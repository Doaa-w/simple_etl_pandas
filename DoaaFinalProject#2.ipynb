# %%
import pandas as pd #تحليل بيانات والخ..
import seaborn as sns #رسم
import numpy as np # التعامل مع مصفوفات ورياضيات
import scipy.stats as stats #احصاء
import matplotlib.pyplot as plt #رسم
import plotly.express as px #رسم
import random
# %matplotlib inline
sns.set(rc={'figure.figsize':(11,8)})

# %% [markdown]
# # Extract
# Extract is getting the data from its source ,and Read to read the file into pandas
#
#  here we have *artistsCh.CSV* file That contains a database for a Chinese Artist that is missing some info as well as wrong data

# %%
# Extract
df_artists = pd.read_csv('/content/artistsCh.csv')
df_artists
# Out:
#     Artist ID                      Name Nationality  Gender Birth Year  \
# 0           1                Ai Xuan 艾軒    Zhejiang    Male       1947
# 1           2        Chang DaiChien 張大千    Neijiang    Male       1899
# 2           3                Chu Chu 儲楚    Hangzhou  Female       1975
# 3           4  Giuseppe Castiglione 郎世宁       Italy    Male       1688
# 4           5              Gu Wenda 谷文达    Shanghai    Male       1955
# 5           6              He Baili 何百里   GuangZhou    Male       1945
# 6           7              He Jilan 何紀嵐   Hong Kong    Male       1974
# 7           9            Irene Chou 周綠雲    Shanghai  Female       1924
# 8          10          Jin TingBiao 金廷标      Huzhou    Male       1767
# 9          11           Li FangYing 李方膺     Jiangsu    Male       1696
# 10         12             Li Zijian 李自健    ShaoYang    Male       1954
# 11         13              Ling Jian 凌健    ShanDong    Male       1963
# ...

# %%
def clean_artists(df: pd.DataFrame) -> pd.DataFrame:
  #هنا نسوي نسخه عشان نشتغل عليها
    out = df.copy()

# %%
#this step is to see the types and an overviwe on my file
df_artists.dtypes
df_artists.info()
df_artists.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Artist ID    35 non-null     int64
#  1   Name         25 non-null     object
#  2   Nationality  25 non-null     object
#  3   Gender       25 non-null     object
#  4   Birth Year   25 non-null     object
#  5   Death Year   8 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 1.8+ KB
#        Artist ID
# count  35.000000
# mean   20.914286
# std    12.176089
# min     1.000000
# 25%    10.500000
# 50%    22.000000
# 75%    31.500000
# max    40.000000

# %% [markdown]
# # Transform
# in this section I wil start clean my data
# -finding the null value and drop it if Unnecessary
#
# *  filling the missing data
# *  droping Unnecessary rows and columns
#
# *   checking if there is a duplication on my Databass
# *   removing the null values
#
#
# *   using condition to viwe specific valuse

# %%
#here i choose to read only where the Artist is Female
df_artists['Gender']
df_artists.loc[df_artists['Gender']=='Female']
# Out:
#    Artist ID            Name Nationality  Gender Birth Year Death Year
# 2          3      Chu Chu 儲楚    Hangzhou  Female       1975        NaN
# 7          9  Irene Chou 周綠雲    Shanghai  Female       1924       2011

# %%
#whatching the empty or the null values on my file
df_artists.isnull()
df_artists.loc[df_artists['Death Year'].isnull()]
df_artists
# Out:
#     Artist ID                      Name Nationality  Gender Birth Year  \
# 0           1                Ai Xuan 艾軒    Zhejiang    Male       1947
# 1           2        Chang DaiChien 張大千    Neijiang    Male       1899
# 2           3                Chu Chu 儲楚    Hangzhou  Female       1975
# 3           4  Giuseppe Castiglione 郎世宁       Italy    Male       1688
# 4           5              Gu Wenda 谷文达    Shanghai    Male       1955
# 5           6              He Baili 何百里   GuangZhou    Male       1945
# 6           7              He Jilan 何紀嵐   Hong Kong    Male       1974
# 7           9            Irene Chou 周綠雲    Shanghai  Female       1924
# 8          10          Jin TingBiao 金廷标      Huzhou    Male       1767
# 9          11           Li FangYing 李方膺     Jiangsu    Male       1696
# 10         12             Li Zijian 李自健    ShaoYang    Male       1954
# 11         13              Ling Jian 凌健    ShanDong    Male       1963
# ...

# %%
#to delete all the null values from the table
df_artists.duplicated().sum()
# Out:
# np.int64(0)

# %%
#see the Artists with a unique age or at least not repeated
uniqueyear = df_artists['Birth Year'].unique()
print(uniqueyear)
# Out:
# ['1947' '1899' '1975' '1688' '1955' '1945' '1974' '1924' '1767' '1696'
#  '1954' '1963' '1932' '1967' '1977' '1948' '1961' '1494' '1938' '1632'
#  '公元18世纪' '1647' '1958' '1941' nan]

# %%
#replace the null with the EMPTY word
df_artists.fillna('EMPTY', inplace=True)
df_artists.dropna()
df_artists.isnull().sum()
df_artists
# Out:
#     Artist ID                      Name Nationality  Gender Birth Year  \
# 0           1                Ai Xuan 艾軒    Zhejiang    Male       1947
# 1           2        Chang DaiChien 張大千    Neijiang    Male       1899
# 2           3                Chu Chu 儲楚    Hangzhou  Female       1975
# 3           4  Giuseppe Castiglione 郎世宁       Italy    Male       1688
# 4           5              Gu Wenda 谷文达    Shanghai    Male       1955
# 5           6              He Baili 何百里   GuangZhou    Male       1945
# 6           7              He Jilan 何紀嵐   Hong Kong    Male       1974
# 7           9            Irene Chou 周綠雲    Shanghai  Female       1924
# 8          10          Jin TingBiao 金廷标      Huzhou    Male       1767
# 9          11           Li FangYing 李方膺     Jiangsu    Male       1696
# 10         12             Li Zijian 李自健    ShaoYang    Male       1954
# 11         13              Ling Jian 凌健    ShanDong    Male       1963
# ...

# %%
#drop all the null values
df_artists.drop(df_artists[df_artists['Artist ID']> 25].index ,inplace=True)
df_artists
# Out:
#     Artist ID                      Name Nationality  Gender Birth Year  \
# 0           1                Ai Xuan 艾軒    Zhejiang    Male       1947
# 1           2        Chang DaiChien 張大千    Neijiang    Male       1899
# 2           3                Chu Chu 儲楚    Hangzhou  Female       1975
# 3           4  Giuseppe Castiglione 郎世宁       Italy    Male       1688
# 4           5              Gu Wenda 谷文达    Shanghai    Male       1955
# 5           6              He Baili 何百里   GuangZhou    Male       1945
# 6           7              He Jilan 何紀嵐   Hong Kong    Male       1974
# 7           9            Irene Chou 周綠雲    Shanghai  Female       1924
# 8          10          Jin TingBiao 金廷标      Huzhou    Male       1767
# 9          11           Li FangYing 李方膺     Jiangsu    Male       1696
# 10         12             Li Zijian 李自健    ShaoYang    Male       1954
# 11         13              Ling Jian 凌健    ShanDong    Male       1963
# ...

# %%
#Chang the column name to more accurate name
df_artists.rename(columns={'Nationality':'City Of Birth'},inplace=True)
df_artists
# Out:
#     Artist ID                      Name City Of Birth  Gender Birth Year  \
# 0           1                Ai Xuan 艾軒      Zhejiang    Male       1947
# 1           2        Chang DaiChien 張大千      Neijiang    Male       1899
# 2           3                Chu Chu 儲楚      Hangzhou  Female       1975
# 3           4  Giuseppe Castiglione 郎世宁         Italy    Male       1688
# 4           5              Gu Wenda 谷文达      Shanghai    Male       1955
# 5           6              He Baili 何百里     GuangZhou    Male       1945
# 6           7              He Jilan 何紀嵐     Hong Kong    Male       1974
# 7           9            Irene Chou 周綠雲      Shanghai  Female       1924
# 8          10          Jin TingBiao 金廷标        Huzhou    Male       1767
# 9          11           Li FangYing 李方膺       Jiangsu    Male       1696
# 10         12             Li Zijian 李自健      ShaoYang    Male       1954
# 11         13              Ling Jian 凌健      ShanDong    Male       1963
# ...

# %%
#here we have a Chiness writing in some colums so we replace it with english writings
df_artists['City Of Birth'].replace({'顺天（今北京）': 'Shuntian (today Beijing)'},inplace=True)
df_artists['Birth Year'].replace({'公元18世纪': '1800'} ,inplace=True)
df_artists['Death Year'].replace({'公元18世纪': '1800'} ,inplace=True)
df_artists
# Out:
# <ipython-input-35-762c6b6fc214>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_artists['City Of Birth'].replace({'顺天（今北京）': 'Shuntian (today Beijing)'},inplace=True)
# <ipython-input-35-762c6b6fc214>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#fill the empty rows
df_artists.loc[df_artists['Name'] == 'Ai Xuan 艾軒', 'Death Year'] = 2003
df_artists.loc[df_artists['Name'] == 'Chu Chu 儲楚', 'Death Year'] = 2025
df_artists.loc[df_artists['Name'] == 'Gu Wenda 谷文达', 'Death Year'] = 2025
df_artists.loc[df_artists['Name'] == 'He Baili 何百里', 'Death Year'] = 2018
df_artists.loc[df_artists['Name'] == 'He Jilan 何紀嵐', 'Death Year'] = 2022
df_artists.loc[df_artists['Name'] == 'Jin TingBiao 金廷标', 'Death Year'] = 1845
df_artists.loc[df_artists['Name'] == 'Li Zijian 李自健', 'Death Year'] = 2011
df_artists.loc[df_artists['Name'] == 'Ling Jian 凌健', 'Death Year'] = 2019
df_artists.loc[df_artists['Name'] == 'Liu KuoSung 刘国松', 'Death Year'] = 1992
df_artists.loc[df_artists['Name'] == 'Liu YuanShou 劉元壽', 'Birth Year'] = 1887
df_artists.loc[df_artists['Name'] == 'Liu YuanShou 劉元壽', 'Death Year'] = 1923
df_artists.loc[df_artists['Name'] == 'Lu XinJian 陆新建', 'Death Year'] = 2006
df_artists.loc[df_artists['Name'] == 'Luo ZhongLi 羅中立', 'Death Year'] = 2024
df_artists.loc[df_artists['Name'] == 'Qin Feng 秦风', 'Death Year'] = 2007
df_artists.loc[df_artists['Name'] == 'Wai Ming', 'Death Year'] = 2010
df_artists.loc[df_artists['Name'] == 'Yao WenHan 姚文瀚', 'Death Year'] = 1893
df_artists
# Out:
#     Artist ID                      Name             City Of Birth  Gender  \
# 0           1                Ai Xuan 艾軒                  Zhejiang    Male
# 1           2        Chang DaiChien 張大千                  Neijiang    Male
# 2           3                Chu Chu 儲楚                  Hangzhou  Female
# 3           4  Giuseppe Castiglione 郎世宁                     Italy    Male
# 4           5              Gu Wenda 谷文达                  Shanghai    Male
# 5           6              He Baili 何百里                 GuangZhou    Male
# 6           7              He Jilan 何紀嵐                 Hong Kong    Male
# 7           9            Irene Chou 周綠雲                  Shanghai  Female
# 8          10          Jin TingBiao 金廷标                    Huzhou    Male
# 9          11           Li FangYing 李方膺                   Jiangsu    Male
# 10         12             Li Zijian 李自健                  ShaoYang    Male
# 11         13              Ling Jian 凌健                  ShanDong    Male
# ...

# %%
#calculate the Artists age
df_artists['Birth Year']=pd.to_numeric(df_artists['Birth Year'], errors='coerce')
df_artists['Death Year']=pd.to_numeric(df_artists['Death Year'], errors='coerce')
ages =df_artists['Death Year'] - df_artists['Birth Year']
ages
# Out:
# 0     56
# 1     84
# 2     50
# 3     78
# 4     70
# 5     73
# 6     48
# 7     87
# 8     78
# 9     59
# 10    57
# 11    56
# 12    60
# 13    36
# 14    29
# 15    76
# 16    46
# 17    58
# 18    72
# 19    85
# 20    93
# dtype: int64

# %% [markdown]
# # load
# load the Data to a new clean file

# %%
df_artists.to_csv('clean_artists.csv', index=False)
print("Clean file written: clean_artists.csv")
print(f"Clean rows: {len(df_artists)}")
# Out:
# Clean file written: clean_artists.csv
# Clean rows: 21

# %% [markdown]
# #  Pipeline function

# %%
def run_etl(input_path: str = 'artistsCh.csv',
             output_path: str = 'clean_artists.csv',
             verbose: bool = True):
    """Simple, reproducible ETL pipeline."""
    if verbose: print('Extract ▶ ', end='')
    df_artist = pd.read_csv(input_path)
    if verbose: print('Transform ▶ ', end='')
    df_artist= clean_artists(df_artist)
    if verbose: print('Load ▶ ', end='')
    df_artists.to_csv(output_path, index=False)
    if verbose: print('Done!')
    return df_artists

# Run the complete pipeline
_ = run_etl()
# Out:
# Extract ▶ Transform ▶ Load ▶ Done!
